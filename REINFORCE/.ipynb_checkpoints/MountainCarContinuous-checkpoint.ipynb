# %% [markdown]
# # doesn't work rn, probably won't work even if i implement the algo correctly, fuck you sparse environments!!

# %%
import gymnasium as gym

import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
from collections import deque

env = gym.make("MountainCarContinuous-v0", render_mode="human")

""" state: Box(x_position, velocity), length=2
    actions: Box(force_on_car), length=1

    -ve: left, +ve: right
"""

def test_run(n_ep, env):
    
    for _ in range(n_ep):
        observation, info = env.reset()
        total_reward = 0

        while True:
            action = env.action_space.sample()
            observation, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            
            total_reward += reward
            # print(total_reward)
            
            if done:
                break

# test_run(1, env)

# %%
# this is literally all you need lmfao
def simple_policy(state):
    return [float(state[1] > 0), "test"]

def test_policy(n_ep, policy, _env):
    reward_list = []
    
    for _ in range(n_ep):
        reward_count = 0
        observation, info = _env.reset()
        
        while True:
            action = policy(observation)
            observation, reward, terminated, truncated, info = _env.step(action)
            reward_count += reward
            # print(observation, action)
            
            if terminated or truncated:
                break
        reward_list.append(reward_count)
    return np.mean(reward_list)

env = gym.make("MountainCarContinuous-v0", render_mode="human")

# test_policy(1, simple_policy, env)
# env.close()

# %%
class policy_net(nn.Module):
    def __init__(self, in_dim, out_dim) -> None:
        super().__init__()
        # note to self: nn.Linear() represents the transformation, not the matrices themselves.
        self.il = nn.Linear(in_dim, 50)
        self.relu = nn.ReLU()

        self.mean_l = nn.Linear(50, out_dim)
        self.log_std_l = nn.Linear(50, out_dim)
    def forward(self, x):
        x = F.relu(self.il(x))

        mean = self.mean_l(x)
        log_std = self.log_std_l(x)
        return mean, log_std

def generate_episode(policy_net, _env):
    # we keep the means as means because we need both action prediction and mean of distribution
    states, log_probs, rewards = [], [], []
    # reset env, get the starting state
    state, info = _env.reset()
    state = torch.tensor(state, dtype=torch.float32)
    # single-goal oriented environment, can track successes, yay
    successes = 0

    while True:
        # add current state to states list
        states.append(state)
        
        # get the predicted mean of distri for current state, add to list of means
        mean, log_std = policy_net.forward(state)
        std = torch.exp(log_std)
        
        gauss = torch.distributions.Normal(mean, std)
        action = gauss.sample()
        log_prob_tensor = gauss.log_prob(action).unsqueeze(0)
        log_probs.append(log_prob_tensor)

        state, reward, terminated, truncated, info = _env.step([action.item(), 0])
        state = torch.tensor(state, dtype=torch.float32)
    
        reward = torch.tensor(reward, dtype=torch.float32)
        rewards.append(reward)
        
        if terminated or truncated:
            if rewards[-1] == 1:
                successes += 1
            break

    return log_probs, rewards

def REINFORCE(_env, n_ep):
    state_dim = _env.observation_space.shape[0]
    action_dim = _env.action_space.shape[0]
    policy = policy_net(state_dim, action_dim)
    optimizer = torch.optim.Adam(policy.parameters(), lr=1e-3)
    gamma = 0.99
        
    for _ in range(n_ep):
        log_probs, rewards = generate_episode(policy, _env)
        returns = []
        policy_loss = []
        disc_return = 0
        
        for R in reversed(rewards):
            disc_return = R + gamma * disc_return
            returns.append(disc_return)

        for G, L in zip(returns, log_probs):
            policy_loss.append(-L * G)

        returns = torch.tensor(returns)
        policy_loss = torch.cat(policy_loss).sum()
        print(policy_loss)
        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()
    return policy

# %%
env = gym.make("MountainCarContinuous-v0")

policy = REINFORCE(env, 100)
env.close()
# Out:
# tensor(-39759.9375, grad_fn=<SumBackward0>)
# tensor(-41882.7344, grad_fn=<SumBackward0>)
# tensor(-46049.6250, grad_fn=<SumBackward0>)
# tensor(-44815.1602, grad_fn=<SumBackward0>)
# tensor(-49757.4922, grad_fn=<SumBackward0>)
# tensor(-45284.3359, grad_fn=<SumBackward0>)
# tensor(-46553.5508, grad_fn=<SumBackward0>)
# tensor(-48433.9219, grad_fn=<SumBackward0>)
# tensor(-44625.4961, grad_fn=<SumBackward0>)
# tensor(-51070.1133, grad_fn=<SumBackward0>)
# tensor(-55179.5898, grad_fn=<SumBackward0>)
# tensor(-56900.0469, grad_fn=<SumBackward0>)
# tensor(-52445.8281, grad_fn=<SumBackward0>)
# tensor(-48027.0312, grad_fn=<SumBackward0>)
# tensor(-47661.2500, grad_fn=<SumBackward0>)
# tensor(-46058.3008, grad_fn=<SumBackward0>)
# tensor(-42798.6211, grad_fn=<SumBackward0>)
# tensor(-45366.5039, grad_fn=<SumBackward0>)
# tensor(-46954.5742, grad_fn=<SumBackward0>)
# tensor(-51098.3711, grad_fn=<SumBackward0>)
# tensor(-18272.1484, grad_fn=<SumBackward0>)
# tensor(-44452.6250, grad_fn=<SumBackward0>)
# tensor(-48388.6133, grad_fn=<SumBackward0>)
# tensor(-48279.1680, grad_fn=<SumBackward0>)
# tensor(-47005.3125, grad_fn=<SumBackward0>)
# tensor(-57249.7188, grad_fn=<SumBackward0>)
# tensor(-50715.0078, grad_fn=<SumBackward0>)
# tensor(-49972.6680, grad_fn=<SumBackward0>)
# tensor(-56569.6055, grad_fn=<SumBackward0>)
# tensor(-45401.6641, grad_fn=<SumBackward0>)
# tensor(-49728.9297, grad_fn=<SumBackward0>)
# tensor(-47764.1211, grad_fn=<SumBackward0>)
# tensor(-46047.0391, grad_fn=<SumBackward0>)
# tensor(-40203.8633, grad_fn=<SumBackward0>)
# tensor(-45665.0469, grad_fn=<SumBackward0>)
# tensor(-44916.3906, grad_fn=<SumBackward0>)
# tensor(-43448.1016, grad_fn=<SumBackward0>)
# tensor(-51644.1562, grad_fn=<SumBackward0>)
# tensor(-44346.9492, grad_fn=<SumBackward0>)
# tensor(-43538.3242, grad_fn=<SumBackward0>)
# tensor(-44281.0117, grad_fn=<SumBackward0>)
# tensor(-45682.0391, grad_fn=<SumBackward0>)
# tensor(-42157.5156, grad_fn=<SumBackward0>)
# tensor(-43985., grad_fn=<SumBackward0>)
# tensor(-39658.4492, grad_fn=<SumBackward0>)
# tensor(-40317.6758, grad_fn=<SumBackward0>)
# tensor(-42436.4727, grad_fn=<SumBackward0>)
# tensor(-41329.0117, grad_fn=<SumBackward0>)
# tensor(-39204.9648, grad_fn=<SumBackward0>)
# tensor(-38038.8438, grad_fn=<SumBackward0>)
# tensor(-47653.2031, grad_fn=<SumBackward0>)
# tensor(-36918.9297, grad_fn=<SumBackward0>)
# tensor(-35803.9336, grad_fn=<SumBackward0>)
# tensor(-39495.0195, grad_fn=<SumBackward0>)
# tensor(-35259.1172, grad_fn=<SumBackward0>)
# tensor(-39767.8203, grad_fn=<SumBackward0>)
# tensor(-35745.5469, grad_fn=<SumBackward0>)
# tensor(-37388.4492, grad_fn=<SumBackward0>)
# tensor(-35748.0703, grad_fn=<SumBackward0>)
# tensor(-37496.3711, grad_fn=<SumBackward0>)
# tensor(-33413.4258, grad_fn=<SumBackward0>)
# tensor(-32680.3418, grad_fn=<SumBackward0>)
# tensor(-34777.9453, grad_fn=<SumBackward0>)
# tensor(-33158.0977, grad_fn=<SumBackward0>)
# tensor(-35164.4609, grad_fn=<SumBackward0>)
# tensor(-34263.0703, grad_fn=<SumBackward0>)
# tensor(-34306.5977, grad_fn=<SumBackward0>)
# tensor(-31631.5156, grad_fn=<SumBackward0>)
# tensor(-34455.2031, grad_fn=<SumBackward0>)
# tensor(-37549.7656, grad_fn=<SumBackward0>)
# tensor(-30226.3809, grad_fn=<SumBackward0>)
# tensor(-35590.8398, grad_fn=<SumBackward0>)
# tensor(-14399.1484, grad_fn=<SumBackward0>)
# tensor(-32432.5039, grad_fn=<SumBackward0>)
# tensor(-37308.7969, grad_fn=<SumBackward0>)
# tensor(-35830.6602, grad_fn=<SumBackward0>)
# tensor(-36609.4648, grad_fn=<SumBackward0>)
# tensor(-35622.7422, grad_fn=<SumBackward0>)
# tensor(-38060.2500, grad_fn=<SumBackward0>)
# tensor(-36604.1641, grad_fn=<SumBackward0>)
# tensor(-36204.7031, grad_fn=<SumBackward0>)
# tensor(-37105.8008, grad_fn=<SumBackward0>)
# tensor(-31156.2090, grad_fn=<SumBackward0>)
# tensor(-38356.4805, grad_fn=<SumBackward0>)
# tensor(-36239.0273, grad_fn=<SumBackward0>)
# tensor(-38998.4883, grad_fn=<SumBackward0>)
# tensor(-33961.4688, grad_fn=<SumBackward0>)
# tensor(-35553.6094, grad_fn=<SumBackward0>)
# tensor(-34575.0859, grad_fn=<SumBackward0>)
# tensor(-37762.7109, grad_fn=<SumBackward0>)
# tensor(-35184.7852, grad_fn=<SumBackward0>)
# tensor(-39268.6211, grad_fn=<SumBackward0>)
# tensor(-31360.4121, grad_fn=<SumBackward0>)
# tensor(-41048.1250, grad_fn=<SumBackward0>)
# tensor(-37787.3750, grad_fn=<SumBackward0>)
# tensor(-35327.9414, grad_fn=<SumBackward0>)
# tensor(5712.5645, grad_fn=<SumBackward0>)
# tensor(-37399.7109, grad_fn=<SumBackward0>)
# tensor(-40529.5938, grad_fn=<SumBackward0>)
# tensor(-34341.7656, grad_fn=<SumBackward0>)

# %%
def test_policy_net(policy, _env):
    observation, info = _env.reset()
    observation = torch.tensor(observation)

    while True:
        mean, log_std = policy.forward(observation)
        std = torch.exp(log_std)
        
        gauss = torch.distributions.Normal(mean, std)
        action = gauss.sample()
        
        observation, reward, terminated, truncated, info = _env.step(action)
        observation = torch.tensor(observation)
        
        if terminated or truncated or reward < -100:
            break

env = gym.make("MountainCarContinuous-v0", render_mode="human")
test_policy_net(policy, env)
env.close()
